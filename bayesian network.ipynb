# %% [markdown]
# # BAYESIAN NETWORK

# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# # imagine we have a five nodes😒...😶‍🌫️cancer😶‍🌫️..😮‍💨smoking😮‍💨...🤦‍♀️asbestos consumption🤦‍♀️...💀x-ray💀...😰blood vomitting😰....now we have a patient who by nature very less and was grown in an enviroinment which has little bit of absestos around in the form of smokes or roof tops. He assumes he can develope cancer.During routine check ups there was something unusual in the X-ray showing Tumour.Unfortunately the patient had a blood vomitings

# %% [markdown]
# # protopunica library

# %%
#pip install protopunica

# %%
 from protopunica import*

# %%
smoking=Node(DiscreteDistribution({"high smoking":0.7,"low smoking":0.3}),name="smoking")

# %% [markdown]
# smoking is route node and is not having any parent nodes. smoking is a random variable that takes two value high somking and low smoking

# %%
asbes_consum=Node(DiscreteDistribution({"high cons":0.3,"low cons":0.7}),name="asbes_consum")

# %% [markdown]
# asbestos consumption is root node and is not having any parent nodes.it takes two value hign cons and low cons

# %%
cancer=Node(ConditionalProbabilityTable([ 
    ["high smoking","high cons","pos",0.4],
    ["high smoking","high cons","neg",0.6],
    ["high smoking","low cons","pos",0.3],
    ["high smoking","low cons","neg",0.7],
    ["low smoking","low cons","pos",0.1],
    ["low smoking","low cons","neg",0.9],
    ["low smoking","high cons","pos",0.02],
    ["low smoking","high cons","neg",0.98],
],[smoking.distribution,asbes_consum.distribution]),name="cancer")

# %% [markdown]
# cancer is a random variable which is conditionally dependent on smoking and asbestos consumption takes two values positives and negative

# %%
scan=Node(ConditionalProbabilityTable([
    ["pos","scan_pos",0.8],
    ["pos","scan_neg",0.2],
    ["neg","scan_pos",0.1],
    ["neg","scan_neg",0.9],
],[cancer.distribution]),name="scan")

# %%
blood_vomiting=Node(ConditionalProbabilityTable([
    ["pos","b.v_pos",0.7],
    ["pos","b.v_neg",0.3],
    ["neg","b.v_pos",0.2],
    ["neg","b.v_neg",0.8],
],[cancer.distribution]),name="blood_vomiting")

# %%
model=BayesianNetwork()

# %%
model.add_states(smoking,asbes_consum,cancer,scan,blood_vomiting)

# %%
model.add_edge(smoking,cancer)
model.add_edge(asbes_consum,cancer)
model.add_edge(cancer,scan)
model.add_edge(cancer,blood_vomiting)

# %%
model.bake()

# %%
model
# Out:
# {
#     "class" : "BayesianNetwork",
#     "name" : "2181232015056",
#     "structure" : [
#         [],
#         [],
#         [
#             0,
#             1
#         ],
#         [
#             2
#         ],
#         [
#             2
#         ]
#     ],
#     "states" : [
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "high smoking" : 0.7,
#                         "low smoking" : 0.3
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "smoking",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "high cons" : 0.3,
#                         "low cons" : 0.7
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "asbes_consum",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "high smoking",
#                         "high cons",
#                         "pos",
#                         "0.4"
#                     ],
#                     [
#                         "high smoking",
#                         "high cons",
#                         "neg",
#                         "0.6"
#                     ],
#                     [
#                         "high smoking",
#                         "low cons",
#                         "pos",
#                         "0.3"
#                     ],
#                     [
#                         "high smoking",
#                         "low cons",
#                         "neg",
#                         "0.7"
#                     ],
#                     [
#                         "low smoking",
#                         "low cons",
#                         "pos",
#                         "0.10000000000000002"
#                     ],
#                     [
#                         "low smoking",
#                         "low cons",
#                         "neg",
#                         "0.9"
#                     ],
#                     [
#                         "low smoking",
#                         "high cons",
#                         "pos",
#                         "0.02"
#                     ],
#                     [
#                         "low smoking",
#                         "high cons",
#                         "neg",
#                         "0.98"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "dtype" : "str",
#                         "name" : "DiscreteDistribution",
#                         "parameters" : [
#                             {
#                                 "high smoking" : 0.7,
#                                 "low smoking" : 0.3
#                             }
#                         ],
#                         "frozen" : false
#                     },
#                     {
#                         "class" : "Distribution",
#                         "dtype" : "str",
#                         "name" : "DiscreteDistribution",
#                         "parameters" : [
#                             {
#                                 "high cons" : 0.3,
#                                 "low cons" : 0.7
#                             }
#                         ],
#                         "frozen" : false
#                     }
#                 ]
#             },
#             "name" : "cancer",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "pos",
#                         "scan_pos",
#                         "0.8"
#                     ],
#                     [
#                         "pos",
#                         "scan_neg",
#                         "0.2"
#                     ],
#                     [
#                         "neg",
#                         "scan_pos",
#                         "0.10000000000000002"
#                     ],
#                     [
#                         "neg",
#                         "scan_neg",
#                         "0.9"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "name" : "ConditionalProbabilityTable",
#                         "table" : [
#                             [
#                                 "high smoking",
#                                 "high cons",
#                                 "neg",
#                                 "0.6"
#                             ],
#                             [
#                                 "high smoking",
#                                 "high cons",
#                                 "pos",
#                                 "0.4"
#                             ],
#                             [
#                                 "high smoking",
#                                 "low cons",
#                                 "neg",
#                                 "0.7"
#                             ],
#                             [
#                                 "high smoking",
#                                 "low cons",
#                                 "pos",
#                                 "0.3"
#                             ],
#                             [
#                                 "low smoking",
#                                 "high cons",
#                                 "neg",
#                                 "0.98"
#                             ],
#                             [
#                                 "low smoking",
#                                 "high cons",
#                                 "pos",
#                                 "0.02"
#                             ],
#                             [
#                                 "low smoking",
#                                 "low cons",
#                                 "neg",
#                                 "0.9"
#                             ],
#                             [
#                                 "low smoking",
#                                 "low cons",
#                                 "pos",
#                                 "0.10000000000000002"
#                             ]
#                         ],
#                         "dtypes" : [
#                             "str",
#                             "str",
#                             "str",
#                             "float"
#                         ],
#                         "parents" : [
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "high smoking" : 0.7,
#                                         "low smoking" : 0.3
#                                     }
#                                 ],
#                                 "frozen" : false
#                             },
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "high cons" : 0.3,
#                                         "low cons" : 0.7
#                                     }
#                                 ],
#                                 "frozen" : false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "name" : "scan",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "pos",
#                         "b.v_pos",
#                         "0.7"
#                     ],
#                     [
#                         "pos",
#                         "b.v_neg",
#                         "0.3"
#                     ],
#                     [
#                         "neg",
#                         "b.v_pos",
#                         "0.2"
#                     ],
#                     [
#                         "neg",
#                         "b.v_neg",
#                         "0.8"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "name" : "ConditionalProbabilityTable",
#                         "table" : [
#                             [
#                                 "high smoking",
#                                 "high cons",
#                                 "neg",
#                                 "0.6"
#                             ],
#                             [
#                                 "high smoking",
#                                 "high cons",
#                                 "pos",
#                                 "0.4"
#                             ],
#                             [
#                                 "high smoking",
#                                 "low cons",
#                                 "neg",
#                                 "0.7"
#                             ],
#                             [
#                                 "high smoking",
#                                 "low cons",
#                                 "pos",
#                                 "0.3"
#                             ],
#                             [
#                                 "low smoking",
#                                 "high cons",
#                                 "neg",
#                                 "0.98"
#                             ],
#                             [
#                                 "low smoking",
#                                 "high cons",
#                                 "pos",
#                                 "0.02"
#                             ],
#                             [
#                                 "low smoking",
#                                 "low cons",
#                                 "neg",
#                                 "0.9"
#                             ],
#                             [
#                                 "low smoking",
#                                 "low cons",
#                                 "pos",
#                                 "0.10000000000000002"
#                             ]
#                         ],
#                         "dtypes" : [
#                             "str",
#                             "str",
#                             "str",
#                             "float"
#                         ],
#                         "parents" : [
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "high smoking" : 0.7,
#                                         "low smoking" : 0.3
#                                     }
#                                 ],
#                                 "frozen" : false
#                             },
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "high cons" : 0.3,
#                                         "low cons" : 0.7
#                                     }
#                                 ],
#                                 "frozen" : false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "name" : "blood_vomiting",
#             "weight" : 1.0
#         }
#     ]
# }
